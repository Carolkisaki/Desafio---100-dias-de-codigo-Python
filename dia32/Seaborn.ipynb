# %%
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns

# %% [markdown]
# ### Criando Gráficos com Seaborn

# %%
dados = sns.load_dataset("tips")

# %%
dados.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Relação entre total da conta e gorjeta, através de um gráfico do tipo reg, ou seja, linha de regressão
sns.jointplot(data = dados, x = "total_bill", y = "tip", kind = 'reg')

# %%
#estudando duas variáveis com base em uma terceira variável
sns.lmplot(data = dados, x = "total_bill", y = "tip", col = "smoker")

# %%
#Construindo um dataframe vazio
df = pd.DataFrame()

# %%
df['idade'] = random.sample(range(20, 100), 30)
df['peso'] = random.sample(range(55, 150), 30)

# %%
df.shape
# Out:
# (30, 2)

# %% [markdown]
# 30 linhas e duas colunas

# %%
df.head()
# Out:
#    idade  peso
# 0     60    71
# 1     62   134
# 2     86   136
# 3     88   114
# 4     98    84

# %%
#Criando modelo de regressão com fit_reg
sns.lmplot(data = df, x = "idade", y = "peso", fit_reg = True)

# %% [markdown]
# Esse gráfico mostra uma orientação de baixo pra cima, então provavelmente há uma correlação positiva entre esses dados analisados. Então a partir que aumenta a idade, o peso também aumenta. Se fosse o contrário, seria uma correlação negativa, e se a linha estivesse praticamente reta, seria uma correlação neutra

# %%
sns.kdeplot(df.idade)
# Out:
# <Axes: xlabel='idade', ylabel='Density'>

# %%
sns.kdeplot(df.peso)
# Out:
# <Axes: xlabel='peso', ylabel='Density'>

# %%
sns.distplot(df.peso)
# Out:
# <Axes: xlabel='peso', ylabel='Density'>

# %%
plt.hist(df.idade, alpha = .3)
sns.rugplot(df.idade) #para indicar exatamente os valores das idades
# Out:
# <Axes: xlabel='idade'>

# %%
sns.boxplot(df.idade, color = 'g')
# Out:
# <Axes: ylabel='idade'>

# %%
sns.boxplot(df.peso, color = 'r')
# Out:
# <Axes: ylabel='peso'>

# %%
sns.violinplot(df.idade, color = 'm')
# Out:
# <Axes: ylabel='idade'>

# %%
sns.violinplot(df.peso, color = 'y')
# Out:
# <Axes: ylabel='peso'>

# %%
sns.clustermap(df)

# %% [markdown]
# ### Usando Matplotlib, Seaborn, Numpy e Pandas na Criação de Gráfico Estatístico

# %%
np.random.seed(42)
n = 1000
pct_smokers = 0.2 # 0,2% são pessoas fumantes

#Variáveis
flag_fumante = np.random.rand(n) < pct_smokers # < faz comparação e retorna verdeiro ou falso
idade = np.random.normal(40, 10, n)
altura = np.random.normal(170, 10, n)
peso = np.random.normal(70, 10, n)

#Dataframe
dados = pd.DataFrame({'altura': altura, 'peso': peso, 'flag_fumante': flag_fumante})

dados['flag_fumante'] = dados['flag_fumante'].map({True: 'Fumante', False: 'Não Fumante'})

# %%
dados.shape
# Out:
# (1000, 3)

# %% [markdown]
# 1000 linhas e 3 colunas

# %%
dados.head()
# Out:
#        altura       peso flag_fumante
# 0  155.936825  78.745171  Não Fumante
# 1  169.168944  63.502348  Não Fumante
# 2  154.952796  57.967991  Não Fumante
# 3  177.600560  59.579556  Não Fumante
# 4  170.824398  65.127971      Fumante

# %%
sns.set(style = "ticks") #criando um estilo

sns.lmplot(x = 'altura',
           y = 'peso',
           data = dados,
           hue = 'flag_fumante',
           palette = ['tab:blue', 'tab:orange'],
           height = 7)

plt.xlabel('Altura (cm)')
plt.ylabel('Peso (kg)')
plt.title('Relação entre Altura e Peso de Fumantes e Não Fumantes')

sns.despine() #remove as bordas

plt.show()

# %% [markdown]
# A linha azul parece indicar que não há uma relação entre altura e peso quando a pessoa não é fumante. Agora a linha laranja parece indicar uma relação positiva entre altura e peso quando a pessoa é fumante, isso significa que quando a pessoa fuma, quanto maior a altura, maior o peso
